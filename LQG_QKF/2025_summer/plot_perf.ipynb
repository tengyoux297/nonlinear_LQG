# %%
import pickle
import os
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

# Set paths
perf_dir = 'D:/AC/UCLA/ECE/UCLA_LEMUR/nonlinear_LQG/LQG_QKF/2025_summer/perf/'
pkl_dir = 'D:/AC/UCLA/ECE/UCLA_LEMUR/nonlinear_LQG/LQG_QKF/2025_summer/pkl/'

# Set publication-ready plotting style (matching LQG_QKF.py)
plt.style.use('default')
mpl.rcParams['font.family'] = 'serif'
mpl.rcParams['font.serif'] = ['Times New Roman', 'DejaVu Serif', 'Computer Modern Roman']
mpl.rcParams['font.size'] = 10
mpl.rcParams['axes.titlesize'] = 12
mpl.rcParams['axes.labelsize'] = 10
mpl.rcParams['xtick.labelsize'] = 9
mpl.rcParams['ytick.labelsize'] = 9
mpl.rcParams['legend.fontsize'] = 9
mpl.rcParams['figure.titlesize'] = 14
mpl.rcParams['lines.linewidth'] = 2
mpl.rcParams['axes.linewidth'] = 1.2
mpl.rcParams['grid.linewidth'] = 0.8
mpl.rcParams['grid.alpha'] = 0.3

# Publication-ready color palette (matching LQG_QKF.py)
PUBLICATION_COLORS = {
    'ekf': '#1f77b4',      # Blue
    'ukf': '#2ca02c',      # Green  
    'qkf': '#ff7f0e',      # Orange
    'qkf_analytic': '#d62728',  # Red
    'grid': '#e0e0e0',
    'text': '#2f2f2f'
}

# %%
# with m scale = 100
mscale = int(1e2)
lqe_qkf_results_all = pickle.load(open(os.path.join(pkl_dir, f'lqe_qkf_results-mscale={int(mscale)}.pkl'), 'rb'))
ekf_results_all = pickle.load(open(os.path.join(pkl_dir, f'ekf_results-mscale={int(mscale)}.pkl'), 'rb'))
qkf_results_all = pickle.load(open(os.path.join(pkl_dir, f'qkf_results-mscale={int(mscale)}.pkl'), 'rb'))


err_list_lqe_qkf_all = lqe_qkf_results_all[0]
var_list_lqe_qkf_all = lqe_qkf_results_all[1]

err_list_ekf_all = ekf_results_all[0]
var_list_ekf_all = ekf_results_all[1]
cost_list_ekf_all = ekf_results_all[2]

err_list_qkf_all = qkf_results_all[0]
var_list_qkf_all = qkf_results_all[1]
cost_list_qkf_all = qkf_results_all[2]

err_list_lqe_qkf_avg = np.mean(err_list_lqe_qkf_all, axis=0)
var_list_lqe_qkf_avg = np.mean(var_list_lqe_qkf_all, axis=0)
err_list_ekf_avg = np.mean(err_list_ekf_all, axis=0)
err_list_qkf_avg = np.mean(err_list_qkf_all, axis=0)
var_list_ekf_avg = np.mean(var_list_ekf_all, axis=0)
var_list_qkf_avg = np.mean(var_list_qkf_all, axis=0)
cost_list_ekf_avg = np.mean(cost_list_ekf_all, axis=0)
cost_list_qkf_avg = np.mean(cost_list_qkf_all, axis=0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 # with m scale = 100
#       2 mscale = int(1e2)
# ----> 3 lqe_qkf_results_all = pickle.load(open(os.path.join(pkl_dir, f'lqe_qkf_results-mscale={int(mscale)}.pkl'), 'rb'))
#       4 ekf_results_all = pickle.load(open(os.path.join(pkl_dir, f'ekf_results-mscale={int(mscale)}.pkl'), 'rb'))
#       5 qkf_results_all = pickle.load(open(os.path.join(pkl_dir, f'qkf_results-mscale={int(mscale)}.pkl'), 'rb'))
#
# File d:\anaconda\envs\lqg\lib\site-packages\IPython\core\interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:/AC/UCLA/ECE/UCLA_LEMUR/nonlinear_LQG/LQG_QKF/2025_summer/pkl/lqe_qkf_results-mscale=100.pkl'

# %%
# --- Estimation Error Plot (LQE-QKF vs LQG-QKF) ---
sns.set_theme(style="whitegrid", font_scale=1.6, rc={"lines.linewidth": 1.5})

fig_err, ax_err = plt.subplots(figsize=(12, 5))
sns.lineplot(
    x=np.arange(len(err_list_lqe_qkf_avg)), y=err_list_lqe_qkf_avg, 
    label='QKF (no control)', color='blue', ax=ax_err, linewidth=1.2
)
sns.lineplot(
    x=np.arange(len(err_list_qkf_avg)), y=err_list_qkf_avg, 
    label='iLQG-QKF', color='orange', ax=ax_err, linewidth=1.2
)
ax_err.set_title(f'Estimation Error, Nonlinearity Factor={mscale}', fontsize=20, pad=10)
ax_err.set_xlabel('Time Step', fontsize=20)
ax_err.set_ylabel('Error', fontsize=20)
ax_err.legend(fontsize=20, frameon=True)
ax_err.grid(True, which='both', linestyle='--', linewidth=0.7, alpha=0.8)
sns.despine()
plt.tight_layout()
# plt.savefig(os.path.join(perf_dir, f'estimation_error-mscale={int(mscale)}.png'), dpi=300, bbox_inches='tight')
plt.show()

# --- Estimation Variance Plot (LQE-QKF vs LQG-QKF) ---
fig_var, ax_var = plt.subplots(figsize=(12, 5))
sns.lineplot(
    x=np.arange(len(var_list_lqe_qkf_avg)), y=var_list_lqe_qkf_avg, 
    label='QKF (no control)', color='blue', ax=ax_var, linewidth=1.2
)
sns.lineplot(
    x=np.arange(len(var_list_qkf_avg)), y=var_list_qkf_avg, 
    label='iLQG-QKF', color='orange', ax=ax_var, linewidth=1.2
)
ax_var.set_title(f'Estimation Variance, Nonlinearity Factor={mscale}', fontsize=20, pad=10)
ax_var.set_xlabel('Time Step', fontsize=20)
ax_var.set_ylabel('Variance', fontsize=20)
ax_var.legend(fontsize=20, frameon=True)
ax_var.grid(True, which='both', linestyle='--', linewidth=0.7, alpha=0.8)
sns.despine()
plt.tight_layout()
plt.savefig(os.path.join(perf_dir, f'estimation_variance-mscale={int(mscale)}.png'), dpi=300, bbox_inches='tight')
plt.show()

# %%
# --- Estimation Error Plot ---
sns.set_theme(style="whitegrid", font_scale=1.6, rc={"lines.linewidth": 1.5})

fig_err, ax_err = plt.subplots(figsize=(12, 5))
sns.lineplot(
    x=np.arange(len(err_list_ekf_avg)), y=err_list_ekf_avg, 
    label='EKF', color='blue', ax=ax_err, linewidth=1.5
)
sns.lineplot(
    x=np.arange(len(err_list_qkf_avg)), y=err_list_qkf_avg, 
    label='QKF', color='orange', ax=ax_err, linewidth=1.5
)
ax_err.set_title(f'Estimation Error, Nonlinearity Factor={mscale}', fontsize=20, pad=10)
ax_err.set_xlabel('Time Step', fontsize=20)
ax_err.set_ylabel('Error', fontsize=20)
ax_err.legend(fontsize=20, frameon=True)
ax_err.grid(True, which='both', linestyle='--', linewidth=0.7, alpha=0.8)
sns.despine()
plt.tight_layout()
plt.savefig(os.path.join(perf_dir, f'estimate_error-mscale={int(mscale)}.png'), dpi=300, bbox_inches='tight')
plt.show()

# --- Estimation Vriance Plot ---
fig_cov, ax_cov = plt.subplots(figsize=(12, 5))
sns.lineplot(
    x=np.arange(len(var_list_ekf_avg)), y=var_list_ekf_avg, 
    label='EKF', color='blue', ax=ax_cov, linewidth=1.5
)
sns.lineplot(
    x=np.arange(len(var_list_qkf_avg)), y=var_list_qkf_avg, 
    label='QKF', color='orange', ax=ax_cov, linewidth=1.5
)
ax_cov.set_title(f'Estimation Variance, Nonlinearity Factor={mscale}', fontsize=20, pad=10)
ax_cov.set_xlabel('Time Step', fontsize=20)
ax_cov.set_ylabel('Total Variance', fontsize=20)
ax_cov.legend(fontsize=20, frameon=True)
ax_cov.grid(True, which='both', linestyle='--', linewidth=0.7, alpha=0.8)
sns.despine()
plt.tight_layout()
# plt.savefig(os.path.join(perf_dir, f'estimate_variance-mscale={int(mscale)}.png'), dpi=300, bbox_inches='tight')
plt.show()

# %%
# plot: cost-to-go vs. time (polished version)
sns.set_theme(style="whitegrid", font_scale=1.6, rc={"lines.linewidth": 1.5})

fig, ax = plt.subplots(figsize=(12, 5))
sns.lineplot(
    x=np.arange(len(cost_list_ekf_avg)), y=cost_list_ekf_avg, 
    label='LQG-EKF', color='blue', ax=ax, linewidth=1.2
)
sns.lineplot(
    x=np.arange(len(cost_list_qkf_avg)), y=cost_list_qkf_avg, 
    label='iLQG-QKF', color='orange', ax=ax, linewidth=1.2
)
ax.set_title(f'Cost-to-Go vs. Time, Nonlinearity Factor={mscale}', fontsize=20, pad=10)
ax.set_xlabel('Time Step', fontsize=20)
ax.set_ylabel('Cost-to-Go', fontsize=20)
ax.legend(fontsize=20, frameon=True)
ax.grid(True, which='both', linestyle='--', linewidth=0.7, alpha=0.8)
sns.despine()

plt.tight_layout()
plt.savefig(os.path.join(perf_dir, f'cost_perf-mscale={int(mscale)}.png'), dpi=300, bbox_inches='tight')
plt.show()

# %%
# plot convergence vs. trial (polished version)
sns.set_theme(style="whitegrid", font_scale=1.6, rc={"lines.linewidth": 2.5})

trials = 20
H = 1000  # horizon length
convergence_list_ekf = [H] * trials
convergence_list_qkf = [H] * trials
epsilon = 1e2

for trial in range(trials):
    for timestep in range(H):
        if cost_list_ekf_all[trial][timestep] < epsilon:
            convergence_list_ekf[trial] = timestep
            break        
    for timestep in range(H):
        if cost_list_qkf_all[trial][timestep] < epsilon:
            convergence_list_qkf[trial] = timestep
            break

fig, ax = plt.subplots(figsize=(12, 5))
sns.scatterplot(x=np.arange(1, trials + 1), y=convergence_list_ekf, label='EKF', color='blue', s=100, marker='o', ax=ax)
sns.scatterplot(x=np.arange(1, trials + 1), y=convergence_list_qkf, label='QKF', color='orange', s=100, marker='s', ax=ax)
sns.lineplot(x=np.arange(1, trials + 1), y=convergence_list_ekf, color='blue', ax=ax, linewidth=1.5, alpha=0.5)
sns.lineplot(x=np.arange(1, trials + 1), y=convergence_list_qkf, color='orange', ax=ax, linewidth=1.5, alpha=0.5)

ax.set_title(f'Convergence Time (ε={epsilon:.0e}), Nonlinearity Factor={mscale}', fontsize=20, pad=15)
ax.set_xlabel('Trial Number', fontsize=20)
ax.set_ylabel('Convergence Time (Steps)', fontsize=20)
ax.set_xticks(np.arange(1, trials + 1, 1))
ax.legend(fontsize=20, frameon=True)
ax.grid(True, which='both', linestyle='--', linewidth=0.7, alpha=0.7)
sns.despine()

plt.tight_layout()
# plt.savefig(os.path.join(perf_dir, f'convergence_perf-mscale={int(mscale)}.png'), dpi=300, bbox_inches='tight')
plt.show()

# %%
# plot: cost-to-go vs. non-linearity (publication-ready style)
# Apply publication-ready matplotlib settings (matching LQG_QKF.py)
import matplotlib as mpl

# Set publication-ready plotting style
plt.style.use('default')
mpl.rcParams['font.family'] = 'serif'
mpl.rcParams['font.serif'] = ['Times New Roman', 'DejaVu Serif', 'Computer Modern Roman']
mpl.rcParams['font.size'] = 10
mpl.rcParams['axes.titlesize'] = 12
mpl.rcParams['axes.labelsize'] = 10
mpl.rcParams['xtick.labelsize'] = 9
mpl.rcParams['ytick.labelsize'] = 9
mpl.rcParams['legend.fontsize'] = 9
mpl.rcParams['figure.titlesize'] = 14
mpl.rcParams['lines.linewidth'] = 2
mpl.rcParams['axes.linewidth'] = 1.2
mpl.rcParams['grid.linewidth'] = 0.8
mpl.rcParams['grid.alpha'] = 0.3

# Publication-ready color palette (matching LQG_QKF.py)
PUBLICATION_COLORS = {
    'ekf': '#1f77b4',      # Blue
    'ukf': '#2ca02c',      # Green  
    'qkf': '#ff7f0e',      # Orange
    'qkf_analytic': '#d62728',  # Red
    'grid': '#e0e0e0',
    'text': '#2f2f2f'
}

# mscales = [0, 1, 1e1, 1e2, 1e3, 1e4]
mscales = [0, 1e1, 1e3]
fig, ax = plt.subplots(len(mscales), 1, figsize=(12, 4 * len(mscales) + 2), sharex=True)
fig.suptitle('Cost-to-Go vs. System Nonlinearity', fontsize=24, fontweight='bold', y=0.96)

for idx, mscale in enumerate(mscales):
    # load data
    ekf_results_all = pickle.load(open(os.path.join(pkl_dir, f'ekf_results-mscale={int(mscale)}.pkl'), 'rb'))
    qkf_results_all = pickle.load(open(os.path.join(pkl_dir, f'qkf_results-mscale={int(mscale)}.pkl'), 'rb'))
    ukf_results_all = pickle.load(open(os.path.join(pkl_dir, f'ukf_results-mscale={int(mscale)}.pkl'), 'rb'))
    cost_list_ekf_all = ekf_results_all[2]
    cost_list_qkf_all = qkf_results_all[2]
    cost_list_ukf_all = ukf_results_all[2]
    cost_list_ekf_avg = np.mean(cost_list_ekf_all, axis=0)
    cost_list_qkf_avg = np.mean(cost_list_qkf_all, axis=0)
    cost_list_ukf_avg = np.mean(cost_list_ukf_all, axis=0)

    # Plot with publication-ready styling
    ax[idx].plot(cost_list_ekf_avg, label='LQG+EKF', color=PUBLICATION_COLORS['ekf'], linewidth=2.5)
    ax[idx].plot(cost_list_ukf_avg, label='LQG+UKF', color=PUBLICATION_COLORS['ukf'], linewidth=2.5)
    ax[idx].plot(cost_list_qkf_avg, label='iLQG+QKF', color=PUBLICATION_COLORS['qkf'], linewidth=2.5)
    
    # Enhanced styling
    ax[idx].set_title(f'Nonlinearity Factor m = {int(mscale)}', fontsize=20, fontweight='bold', pad=15)
    ax[idx].set_ylabel('Cost-to-Go', fontsize=20, fontweight='bold')
    ax[idx].legend(frameon=True, fancybox=True, shadow=True, fontsize=20)
    ax[idx].grid(True, alpha=0.3, linestyle='--')
    ax[idx].tick_params(axis='both', which='major', labelsize=9)

# Enhanced bottom subplot
ax[-1].set_xlabel('Time Step', fontsize=20, fontweight='bold')

plt.tight_layout()
plt.subplots_adjust(top=0.90, bottom=0.08, left=0.1, right=0.95, hspace=0.4)
plt.savefig(os.path.join(perf_dir, 'cost_perf_vs_nonlinearity.png'), dpi=300, bbox_inches='tight', facecolor='white')
plt.show()
